# %%
# IMPORTING major libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('Customer Call List.xlsx')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.shape
# Out:
# (21, 8)

# %%
# 4 tpes of problems

completeness - null values and this is a major issue, can not make visualization
validity - duplicacy issue eg:- same pateient ids 
accuracy - eg:- weight i\of adult is 17 kg not valid 
inconsistency -

# %%
# validity issues

df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                         Address Paying Customer Do_Not_Contact  \
# 20  910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 20               True

# %%
# drop_duplicates 

df.drop_duplicates()
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.shape
# Out:
# (21, 8)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
# 2 ways of dropping a column

#df.drop(columns='Not_Useful_Column')
df.drop('Not_Useful_Column',axis=1,inplace = True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
# strip , lstrip,rstrip

df.Last_Name.str.strip('/._')
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.Last_Name = df.Last_Name.str.strip('/._')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df.Phone_Number.str

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       20 non-null     int64
#  1   First_Name       20 non-null     object
#  2   Last_Name        19 non-null     object
#  3   Phone_Number     18 non-null     object
#  4   Address          20 non-null     object
#  5   Paying Customer  20 non-null     object
#  6   Do_Not_Contact   16 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.2+ KB

# %%
df.Phone_Number.str.replace('[^a-zA-Z0-9]','',regex=True)
# Out:
# 0     1235455421
# 1     1236439775
# 2     7066950392
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            nan
# 7     8766783469
# 8            nan
# 9     1235455421
# 10           nan
# 11    7066950392
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17    7066950392
# 18           nan
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
df.Phone_Number=df.Phone_Number.str.replace('[^0-9]','',regex=True)

# %%
df.Phone_Number
# Out:
# 0     1235455421
# 1     1236439775
# 2     7066950392
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6
# 7     8766783469
# 8
# 9     1235455421
# 10
# 11    7066950392
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17    7066950392
# 18
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
df.Phone_Number
# Out:
# 0     1235455421
# 1     1236439775
# 2     7066950392
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6
# 7     8766783469
# 8
# 9     1235455421
# 10
# 11    7066950392
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17    7066950392
# 18
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
np.where(df.Phone_Number=='',np.nan,df.Phone_Number)
# Out:
# array(['1235455421', '1236439775', '7066950392', '1235432345',
#        '8766783469', '3047622467', nan, '8766783469', nan, '1235455421',
#        nan, '7066950392', '1235432345', '8766783469', '3047622467',
#        '1235455421', '1236439775', '7066950392', nan, '8766783469'],
#       dtype=object)

# %%
df.Phone_Number =np.where(df.Phone_Number=='',np.nan,df.Phone_Number)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 1         1002       Abed       Nadir   1236439775              No
# 2         1003     Walter       White   7066950392              No
# 3         1004     Dwight     Schrute   1235432345             Yes
# 4         1005        Jon        Snow   8766783469             Yes
# 5         1006        Ron     Swanson   3047622467             Yes
# 6         1007       Jeff      Winger          NaN              No
# 7         1008   Sherlock      Holmes   8766783469              No
# 8         1009    Gandalf         NaN          NaN             Yes
# 9         1010      Peter      Parker   1235455421             Yes
# 10        1011    Samwise      Gamgee          NaN             Yes
# 11        1012      Harry      Potter   7066950392             Yes
# 12        1013        Don      Draper   1235432345             Yes
# ...

# %%
#np.where(condition,value,where)

# %%
df.Phone_Number
# Out:
# 0     1235455421
# 1     1236439775
# 2     7066950392
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            NaN
# 7     8766783469
# 8            NaN
# 9     1235455421
# 10           NaN
# 11    7066950392
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17    7066950392
# 18           NaN
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
# formatting
df.Phone_Number=df.Phone_Number.apply(lambda x: str(x))
df.Phone_Number=df.Phone_Number.apply(lambda x:x[0:3]+'-'+x[3:6]+'-'+x[6:]).str.rstrip('-')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           nan
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN           nan
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           nan
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
df['Paying Customer']=np.where(df['Paying Customer']=='Y','Yes',df['Paying Customer']) # yes

df['Paying Customer']=np.where(df['Paying Customer']=='N','No',df['Paying Customer']) # no
df['Paying Customer']=np.where(df['Paying Customer']=='N/a','Yes',df['Paying Customer']) # N/a

# %%
df['Paying Customer']
# Out:
# 0     Yes
# 1      No
# 2      No
# 3     Yes
# 4     Yes
# 5     Yes
# 6      No
# 7      No
# 8     Yes
# 9     Yes
# 10    Yes
# 11    Yes
# 12    Yes
# 13    Yes
# 14     No
# 15     No
# 16    Yes
# 17    Yes
# 18    Yes
# 19    Yes
# Name: Paying Customer, dtype: object

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 1         1002       Abed       Nadir   1236439775              No
# 2         1003     Walter       White   7066950392              No
# 3         1004     Dwight     Schrute   1235432345             Yes
# 4         1005        Jon        Snow   8766783469             Yes
# 5         1006        Ron     Swanson   3047622467             Yes
# 6         1007       Jeff      Winger          NaN              No
# 7         1008   Sherlock      Holmes   8766783469              No
# 8         1009    Gandalf         NaN          NaN             Yes
# 9         1010      Peter      Parker   1235455421             Yes
# 10        1011    Samwise      Gamgee          NaN             Yes
# 11        1012      Harry      Potter   7066950392             Yes
# 12        1013        Don      Draper   1235432345             Yes
# ...

# %%
df['Do_Not_Contact']=np.where(df['Do_Not_Contact']=='Y','Yes',df['Do_Not_Contact']) # yes

df['Do_Not_Contact']=np.where(df['Do_Not_Contact']=='N','No',df['Do_Not_Contact']) # no

# %%
df['Do_Not_Contact']
# Out:
# 0      No
# 1     Yes
# 2     NaN
# 3     Yes
# 4      No
# 5     Yes
# 6      No
# 7      No
# 8     NaN
# 9      No
# 10     No
# 11    NaN
# 12     No
# 13     No
# 14     No
# 15     No
# 16     No
# 17    NaN
# 18    Yes
# 19     No
# Name: Do_Not_Contact, dtype: object

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 1         1002       Abed       Nadir   1236439775              No
# 2         1003     Walter       White   7066950392              No
# 3         1004     Dwight     Schrute   1235432345             Yes
# 4         1005        Jon        Snow   8766783469             Yes
# 5         1006        Ron     Swanson   3047622467             Yes
# 6         1007       Jeff      Winger          NaN              No
# 7         1008   Sherlock      Holmes   8766783469              No
# 8         1009    Gandalf         NaN          NaN             Yes
# 9         1010      Peter      Parker   1235455421             Yes
# 10        1011    Samwise      Gamgee          NaN             Yes
# 11        1012      Harry      Potter   7066950392             Yes
# 12        1013        Don      Draper   1235432345             Yes
# ...

# %%
df.Address
# Out:
# 0                     123 Shire Lane, Shire
# 1                       93 West Main Street
# 2                        298 Drugs Driveway
# 3     980 Paper Avenue, Pennsylvania, 18503
# 4                          123 Dragons Road
# 5                          768 City Parkway
# 6                         1209 South Street
# 7                             98 Clue Drive
# 8                          123 Middle Earth
# 9                25th Main Street, New York
# 10                    612 Shire Lane, Shire
# 11                     2394 Hogwarts Avenue
# 12                         2039 Main Street
# 13                         343 City Parkway
# 14                            214 HR Avenue
# 15                     2395 Hogwarts Avenue
# 16           121 Paper Avenue, Pennsylvania
# 17                          3498 Super Lane
# 18                                      N/a
# 19              910 Tatooine Road, Tatooine
# Name: Address, dtype: object

# %%
df.Address.str.split(',')
# Out:
# 0                      [123 Shire Lane,  Shire]
# 1                         [93 West Main Street]
# 2                          [298 Drugs Driveway]
# 3     [980 Paper Avenue,  Pennsylvania,  18503]
# 4                            [123 Dragons Road]
# 5                            [768 City Parkway]
# 6                           [1209 South Street]
# 7                               [98 Clue Drive]
# 8                            [123 Middle Earth]
# 9                 [25th Main Street,  New York]
# 10                     [612 Shire Lane,  Shire]
# 11                       [2394 Hogwarts Avenue]
# 12                           [2039 Main Street]
# 13                           [343 City Parkway]
# 14                              [214 HR Avenue]
# 15                       [2395 Hogwarts Avenue]
# 16            [121 Paper Avenue,  Pennsylvania]
# 17                            [3498 Super Lane]
# 18                                        [N/a]
# 19               [910 Tatooine Road,  Tatooine]
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           nan
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN           nan
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           nan
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
df[['sreet_address','state','zip']]=df.Address.str.split(',',expand=True)

# %%
df.drop('Address',axis=1,inplace=True)

# %%
df.drop('sreet_address',axis=1,inplace=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123-643-9775              No
# 2         1003     Walter       White  706-695-0392              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876-678-3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger           nan              No
# 7         1008   Sherlock      Holmes  876-678-3469              No
# 8         1009    Gandalf         NaN           nan             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee           nan             Yes
# 11        1012      Harry      Potter  706-695-0392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
df.Phone_Number.str.split(',',expand=True)
# Out:
#                0
# 0   123-545-5421
# 1   123-643-9775
# 2   706-695-0392
# 3   123-543-2345
# 4   876-678-3469
# 5   304-762-2467
# 6            nan
# 7   876-678-3469
# 8            nan
# 9   123-545-5421
# 10           nan
# 11  706-695-0392
# 12  123-543-2345
# 13  876-678-3469
# 14  304-762-2467
# 15  123-545-5421
# 16  123-643-9775
# 17  706-695-0392
# 18           nan
# 19  876-678-3469

# %%
df.dropna(subset='Phone_Number',)
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 1         1002       Abed       Nadir   1236439775              No
# 2         1003     Walter       White   7066950392              No
# 3         1004     Dwight     Schrute   1235432345             Yes
# 4         1005        Jon        Snow   8766783469             Yes
# 5         1006        Ron     Swanson   3047622467             Yes
# 7         1008   Sherlock      Holmes   8766783469              No
# 9         1010      Peter      Parker   1235455421             Yes
# 11        1012      Harry      Potter   7066950392             Yes
# 12        1013        Don      Draper   1235432345             Yes
# 13        1014     Leslie       Knope   8766783469             Yes
# 14        1015       Toby  Flenderson   3047622467              No
# 15        1016        Ron     Weasley   1235455421              No
# ...

# %%
df['Paying Customer'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Paying Customer'>

# %%
sns.countplot(df['First_Name'])
# Out:
# <Axes: xlabel='count', ylabel='First_Name'>

# %%
data=df.First_Name.value_counts()
sns.barplot(x=data.index,y=data)
# Out:
# <Axes: xlabel='First_Name', ylabel='count'>

# %%
df[df['CustomerID'] == 1010]
# Out:
#    CustomerID First_Name Last_Name Phone_Number Paying Customer  \
# 9        1010      Peter    Parker   1235455421             Yes
#
#   Do_Not_Contact      state   zip    street_address
# 9             No   New York  None  25th Main Street

# %%
df['CustomerID'].value_counts()
# Out:
# CustomerID
# 1001    1
# 1002    1
# 1019    1
# 1018    1
# 1017    1
# 1016    1
# 1015    1
# 1014    1
# 1013    1
# 1012    1
# 1011    1
# 1010    1
# 1009    1
# 1008    1
# 1007    1
# 1006    1
# 1005    1
# 1004    1
# 1003    1
# 1020    1
# Name: count, dtype: int64

# %%
df['CustomerID'].unique()
# Out:
# array([1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011,
#        1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020], dtype=int64)

# %%
# want data for before this 
df[df['CustomerID'] < 1010]
# Out:
#    CustomerID First_Name Last_Name Phone_Number Paying Customer  \
# 0        1001      Frodo   Baggins   1235455421             Yes
# 1        1002       Abed     Nadir   1236439775              No
# 2        1003     Walter     White   7066950392              No
# 3        1004     Dwight   Schrute   1235432345             Yes
# 4        1005        Jon      Snow   8766783469             Yes
# 5        1006        Ron   Swanson   3047622467             Yes
# 6        1007       Jeff    Winger          NaN              No
# 7        1008   Sherlock    Holmes   8766783469              No
# 8        1009    Gandalf       NaN          NaN             Yes
#
#   Do_Not_Contact          state     zip       street_address
# 0             No          Shire    None       123 Shire Lane
# 1            Yes           None    None  93 West Main Street
# 2            NaN           None    None   298 Drugs Driveway
# 3            Yes   Pennsylvania   18503     980 Paper Avenue
# ...
